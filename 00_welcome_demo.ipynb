# %% [markdown]
# # Introduction
#
# You are currently looking at a Jupyter Notebook hosted on **Google Colab**. It is a cloud-based environment that lets you write and execute Python code directly in your browser without needing to install anything on your computer.

# %% [markdown]
# # What is Python?
#
# Python is a programming language.
# We use it to give instructions to the computer.
#
# In Data Science, Python helps us:
# - Store data
# - Clean data
# - Analyze data
# - Build models

# %% [markdown]
# ## print() Function
#
# In Python, the print() function is how we tell the computer to show us a result or a message on the screen.

# %%
# Printing a simple message
print("Hello, Learner!")
# Out:
# Hello, Data Science Learner!

# %%
# By giving "#" We are telling python that this is a comment - the computer ignores this.
# We use it to explain what the code does.

# %%
# Doing a simple calculation (Python as a calculator)

print(20 + 25)
# Out:
# 45

# %% [markdown]
# ### Task 1: Print() Function
# 1. Try printing your own name and your favorite hobby using the print() function.
# 2. Use the print() function to find the result of 150 / 3.

# %%
# Write your answers for Task 1 here:
