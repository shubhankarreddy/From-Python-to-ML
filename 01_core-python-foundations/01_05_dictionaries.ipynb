# %% [markdown]
# - [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shubhankarreddy/From-Python-to-ML/blob/main/notebooks/01.Core-Python-Foundations/05.Dictionaries.ipynb) 05. Dictionaries

# %% [markdown]
# # 05 – Dictionaries in Python
#
# A dictionary stores data in **key : value** format.
#
# Think of it like:
#
# Roll Number → Student
# Product ID → Product
# Aadhaar Number → Person
#
# Dictionary = Mapping Structure

# %% [markdown]
# ## 1) Creating a Dictionary
#
# ### Syntax
# - Dictionaries use curly braces `{ }`
# - Each item is written as `key: value`
# - Keys are usually strings (but can be other immutable types)
# - Values can be anything (string, number, list, dict, etc.)

# %%
student = {
    "name": "Rahul",
    "age": 21,
    "course": "Data Science"
}

print(student)
# Out:
# {'name': 'Rahul', 'age': 21, 'course': 'Data Science'}

# %% [markdown]
# ## 2) Accessing Values (using keys)
#
# In lists:
# - we access using index → `arr[0]`
#
# In dictionaries:
# - we access using key → `student["name"]`
#
# ⚠️ Important:
# If a key does not exist and you use `student["x"]`, Python gives **KeyError**.

# %%
print(student["name"])
print(student["age"])
# Out:
# Rahul
# 21

# %% [markdown]
# ## 3) Safe Access with `get()`
#
# To avoid KeyError, use:
# - `dict.get(key)`
#
# If the key is missing:
# - it returns `None` (or a default value you provide)

# %%
print(student.get("course"))
print(student.get("city"))              # missing key → None
print(student.get("city", "Not Found")) # missing key → default value
# Out:
# Data Science
# None
# Not Found

# %% [markdown]
# ## 4) Adding a New Key-Value Pair
#
# If the key does not exist, assigning it will **add** it.

# %%
student["city"] = "Mumbai"
print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'course': 'Data Science', 'city': 'Mumbai'}

# %% [markdown]
# ## 5) Updating an Existing Value
#
# If the key already exists, assigning a new value will **update** it.

# %%
student["age"] = 22
print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'course': 'Data Science', 'city': 'Mumbai'}

# %% [markdown]
# ## 6) Removing Items
#
# Common ways:
# 1. `del dict[key]`
#    - removes the key permanently
#    - gives KeyError if key doesn't exist
#
# 2. `dict.pop(key)`
#    - removes and returns the value
#    - can also take a default if key doesn't exist

# %%
removed_value = student.pop("city")
print("Removed:", removed_value)
print(student)
# Out:
# Removed: Mumbai
# {'name': 'Rahul', 'age': 22, 'course': 'Data Science'}

# %%
# pop with default avoids KeyError

print(student.pop("city", "No such key"))
print(student)
# Out:
# No such key
# {'name': 'Rahul', 'age': 22, 'course': 'Data Science'}

# %% [markdown]
# ## 7) Dictionary "Views": keys(), values(), items()
#
# - `keys()`   → all keys
# - `values()` → all values
# - `items()`  → key-value pairs (tuples)
#
# These are used a lot while exploring data.

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'age', 'course'])
# dict_values(['Rahul', 22, 'Data Science'])
# dict_items([('name', 'Rahul'), ('age', 22), ('course', 'Data Science')])

# %% [markdown]
# ## 8) Nested Dictionary
#
# A dictionary can store another dictionary inside it.
#
# This structure is common in:
# - JSON data
# - APIs
# - Real-world datasets

# %%
students = {
    "student1": {"name": "Aman", "marks": 85},
    "student2": {"name": "Priya", "marks": 90}
}

print(students["student1"])
print(students["student1"]["name"])
# Out:
# {'name': 'Aman', 'marks': 85}
# Aman

# %% [markdown]
# ## Summary
#
# - Dictionary stores data in key:value format
# - Keys must be unique
# - Access using key (not index)
# - Use get() for safe access
# - Add / update using assignment
# - Remove using pop() or del
# - Supports nested structures
